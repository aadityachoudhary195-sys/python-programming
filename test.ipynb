# %%
a = [1,2,3,4]
b = [2,3,4,5,6]
common = []
for i in a:
    if i in b and i not in common:
        common.append(i)
        print(common)
# Out:
# [2]
# [2, 3]
# [2, 3, 4]

# %%
def dummy_mileage_kmpl(engine_l, weight_kg, tyre_in):
    mileage = 28 - 4 * engine_l - 0.006 * (weight_kg - 1000) - 0.7 * (tyre_in - 15)
    return max(5.0, mileage)


def city_highway_kmpl(engine_l, weight_kg, tyre_in):
    base = dummy_mileage_kmpl(engine_l, weight_kg, tyre_in)
    city = 0.85 * base
    highway = 1.10 * base
    return base, city, highway


E = 1.5
W = 1200
T = 16

base, city, highway = city_highway_kmpl(E, W, T)

print("Inputs:", E, "L,", W, "kg,", T, "inch")
print("Base mileage   :", round(base, 2), "km/L")
print("City mileage   :", round(city, 2), "km/L")
print("Highway mileage:", round(highway, 2), "km/L")
# Out:
# Inputs: 1.5 L, 1200 kg, 16 inch
# Base mileage   : 20.1 km/L
# City mileage   : 17.09 km/L
# Highway mileage: 22.11 km/L

# %%
 student = {
    "name":"aditya",
    "age" : 18,
    "course": "python"
}

print(student)
# Out:
# {'name': 'aditya', 'age': 18, 'course': 'python'}

# %%
print(student["name"])
print(student["age"])
# Out:
# aditya
# 18

# %%
a = 45.6
f = type (a)
print (f)
# Out:
# <class 'float'>

# %%
name = "harry"
character1 = name[1]
print(character1)
# Out:
# a

# %%
file = open("day100.txt" ,'w')
file.write('welcome to day 9 of python\n')
file.write("day 9")
file.close()


print("data written successfully")
# Out:
# data written successfully

# %%
file = open("day100.txt", 'r')
content = file.read()
file.close()

print(content)
# Out:
# welcome to day 9 of python
# day 9

# %%
file = open("day100.txt", 'r')

for line in file:
    print(line.strip())

    file.close()
# Out:
# welcome to day 9 of python
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 file = open("day100.txt", 'r')
# ----> 3 for line in file:
#       4     print(line.strip())
#       6     file.close()
#
# ValueError: I/O operation on closed file.

# %%
file = open("day100.txt", 'r')
lines = file.readlines()
file.close()

print("total lines:", len(lines))
# Out:
# total lines: 2

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

print(is_prime(29))
# Out:
# True

# %%
def remove_duplicates(lst):
    unique = []
    for item in lst:
        if item not in unique:
            unique.append(item)
    return unique

print(remove_duplicates([1,2,2,3,4,4,5]))
# Out:
# [1, 2, 3, 4, 5]

# %%
def char_frequency(text):
    freq = {}
    for char in text:
        if char != " ":
            freq[char] = freq.get(char, 0) + 1
            return freq
        
        print(char_frequency("python programming"))

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print("hello, my name is", self.name)

s1 = Student("aditya", 18)
s1.greet()
# Out:
# hello, my name is aditya

# %%
class Calculator:
    def add(self, a, b):
        return a + b

    def subtract(self, a, b):
        return a - b


calc = Calculator()
print(calc.add(10, 10))
print(calc.subtract(90, 67))
# Out:
# 20
# 23

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}

merged = dict1.copy()
merged.update(dict2)

print("Mergeed Dictionary", merged)
# Out:
# Mergeed Dictionary {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
marks = {"Rahul": 84, "Amit": 94, "sneha": 56}
highest = max(marks, key=marks.get)

print("Top Student:", highest)
print("Marks:", marks[highest])
# Out:
# Top Student: Amit
# Marks: 94

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}

mereged = dict1.copy()
merged.update(dict2)

print("Merged Dictionary", merged)
# Out:
# Merged Dictionary {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
marks = {"Rahul":78 , "Amit": 79, "Neha": 56}
highest = max(marks, key=marks.get)

print("Top Student:", highest)
print("Mrks:", marks[highest])
# Out:
# Top Student: Amit
# Mrks: 79

# %%
def check_password(password):
    if len(password) < 6:
        return "Weak Password"
    elif password.isdigit():
        return "Medium Password"  
    else:
        return "Strong Password"  
    
pwd = input("Enter Password: ")
print(check_password(pwd))
# Out:
# Weak Password

# %%
num = int(input("Enter a number: "))
    reverse = 0

    while num > 0:
        digit = num % 10
        reverse = reverse * 10 + digit
        num //= 10

    print("Reversed number is:", reverse)

except ValueError:
    print("Please enter a valid integer.")
# Out:
#   Cell In[2], line 2
#     reverse = 0
#     ^
# IndentationError: unexpected indent
