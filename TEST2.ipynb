# %%
##question2##





class employee:
    company = "aditya ltd"

    def__init__(self, name, salary):
    self.name = name 
    self.salary = salary 

    def show_details(self):
        print(self.name, self.salary, self.company)

        @classmethod
        def change_company(cls, new_name):
            cls.company = new_name

            emp1 = employee("aman",50000)
            emp2 = employee("riyaa",70000)

            print("before change:")
            emp1.show_details()
            emp2.show_details()

            employee.change_company("aditya ltd")

            print("after change:")
            emp1.show_details()
            emp2.show_details()
# Out:
#   Cell In[1], line 10
#     def__init__(self, name, salary):
#                                    ^
# SyntaxError: invalid syntax

# %%
##question1

# %%
##questio3




class MatHelper:
    @staticmethod
    def is_even(num):
        return num%2==0
print(MatHelper.is_even(8))
print(MatHelper.is_even(11))
# Out:
# True
# False

# %%
##question4




class BankAccount:
    def __init__(self, name, balance):
       self.name = name 
       self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount
        print("Deposited:", amount)

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print("Withdrawn:", amount)

        else:
            print("insufficient balance")
    def show_balance(self):
        print("Balance:", self._balance)

acc=BankAccount("aman",1000)
acc.deposit(500)
acc.show_balance()
acc.withdraw(300)
acc.show_balance()
acc.withdraw(1500)
# Out:
# Deposited: 500
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 27
#      25 acc=BankAccount("aman",1000)
#      26 acc.deposit(500)
# ---> 27 acc.show_balance()
#      28 acc.withdraw(300)
#      29 acc.show_balance()
#
# Cell In[5], line 23, in BankAccount.show_balance(self)
#      22 def show_balance(self):
# ---> 23     print("Balance:", self._balance)
#
# AttributeError: 'BankAccount' object has no attribute '_balance'

# %%
##question5

class Student:
    """this is a stdnt class docstring"""
print(Student.__name__)
print(Student.__doc__)
print(Student.__module__)
print(Student.__dict__)
# Out:
# Student
# this is a stdnt class docstring
# __main__
# {'__module__': '__main__', '__doc__': 'this is a stdnt class docstring', '__dict__': <attribute '__dict__' of 'Student' objects>, '__weakref__': <attribute '__weakref__' of 'Student' objects>}
